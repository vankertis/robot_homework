# %% [markdown]
# ### Binary Traffic Sign Classification
#
# This is our first notebook on neural networks. We will start by building a simple neural network that will help us to classify two types of traffic signs. The signs used in this lesson are a processed subset from the famous German Traffic Sign Recognition Database (GTSRB) that can be downloaded [here]().

# %%
import os
import cv2
from time import time
import numpy as np
from sklearn.utils import shuffle

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 6]

# %% [markdown]
# #### Data Loading
#
# Let's now load the data to see what we are dealing with.

# %%
folder = 'subset_homework'

# Load traffic sign class 0
fnames_0 = os.listdir(os.path.join(folder, 'class_id_0'))
images_0 = [cv2.imread(os.path.join(folder, 'class_id_0', f), cv2.IMREAD_UNCHANGED) for f in fnames_0]
labels_0 = [0] * len(images_0)

for cnt, idx in enumerate(np.random.randint(0, len(images_0), 10)):
    plt.subplot(2,5,cnt+1)
    plt.imshow(images_0[idx], cmap='gray', vmin=0, vmax=255)
    plt.title(labels_0[idx]), plt.axis(False)

# %%
# Load traffic sign class 1
fnames_1 = os.listdir(os.path.join(folder, 'class_id_1'))
images_1 = [cv2.imread(os.path.join(folder, 'class_id_1', f), cv2.IMREAD_UNCHANGED) for f in fnames_1]
labels_1 = [1] * len(images_1)

for cnt, idx in enumerate(np.random.randint(0, len(images_1), 10)):
    plt.subplot(2,5,cnt+1)
    plt.imshow(images_1[idx], cmap='gray', vmin=0, vmax=255)
    plt.title(labels_1[idx]), plt.axis(False)

# %%
print('Num samples class_0', len(images_0))
print('Num samples class_1', len(images_1))
# Out:
# Num samples class_0 2220
# Num samples class_1 2250

# %% [markdown]
# #### Prepare Input Data
#
# To train our neural network model, we have to prepare the data to the format the the model actually expects. In our case, this will be numpy arrays.

# %%
# Put both classes together and shuffle the data
images = images_0 + images_1
labels = labels_0 + labels_1
images, labels = shuffle(images, labels)

images = np.array(images)
labels = np.array(labels)

print('Images', images.shape)
print('Labels', labels.shape)
# Out:
# Images (4470, 28, 28)
# Labels (4470,)

# %% [markdown]
# But now we have a problem. We cannot just feed the image to a neuron since the neuron inputs are flat (one dimensional). On the other hand, the images are 2D matrices. Therefore, we need to "flatten" the images to a one dimensional vector of pixels.

# %%
start = time()
pixels = []
for image in images:
    pixels_ = []
    for r in range(image.shape[0]):
        for c in range(image.shape[1]):
            pixels_.append(image[r,c])
    pixels.append(pixels_)
    
pixels = np.array(pixels)/255
stop = time()

print('Shape', pixels.shape)
print('Elapsed time', stop - start)
# Out:
# Shape (4470, 784)
# Elapsed time 0.5683879852294922

# %% [markdown]
# Or, you know, just let make use of our friend numpy :-)

# %%
start = time()
pixels = np.array([image.flatten() for image in images])/255
stop = time()

print('Shape', pixels.shape)
print('Elapsed time', stop - start)
# Out:
# Shape (4470, 784)
# Elapsed time 0.021494150161743164

# %% [markdown]
# Before the training, let's again have a look at some raqndom samples from our dataset.

# %%
for cnt, idx in enumerate(np.random.randint(0, len(images), 10)):    
    plt.subplot(2,5,cnt+1)
    plt.imshow(images[idx], cmap='gray', vmin=0, vmax=255)
    plt.title(labels[idx])

# %% [markdown]
# #### Building the Neural Network
#
# Let's now build our first (and yes, very simple) neural network using Tensorflow. For that, we will need a couple of new imports.

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input

# %% [markdown]
# The following netowork will consist of only one single neuron. It is a very tiny network (not even a network, strictly speaking :-) ) and yet it can be quite powerful.

# %%
inputs = Input(shape=(pixels.shape[1]))
outputs = Dense(1, activation="linear")(inputs)
model = Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 1)                 785
#
# =================================================================
# Total params: 785
# Trainable params: 785
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# Before starting the training, we have to compile the model. During the compilation, we indicate what optimizer we want to use and what loss should be applied for the minimization process.

# %%
model.compile(optimizer ='adam', loss = 'mean_squared_error')

# %% [markdown]
# And let's train :-)

# %%
history = model.fit(pixels, labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
#   1/140 [..............................] - ETA: 18s - loss: 1.1514
# 2024-07-02 17:35:55.191119: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 140/140 [==============================] - 0s 371us/step - loss: 0.3179
# Epoch 2/10
# 140/140 [==============================] - 0s 302us/step - loss: 0.2259
# Epoch 3/10
# 140/140 [==============================] - 0s 310us/step - loss: 0.1872
# Epoch 4/10
# 140/140 [==============================] - 0s 312us/step - loss: 0.1597
# Epoch 5/10
# 140/140 [==============================] - 0s 306us/step - loss: 0.1438
# Epoch 6/10
# 140/140 [==============================] - 0s 317us/step - loss: 0.1318
# Epoch 7/10
# 140/140 [==============================] - 0s 305us/step - loss: 0.1176
# Epoch 8/10
# 140/140 [==============================] - 0s 303us/step - loss: 0.1117
# Epoch 9/10
# 140/140 [==============================] - 0s 324us/step - loss: 0.1060
# Epoch 10/10
# 140/140 [==============================] - 0s 332us/step - loss: 0.0995

# %%
# Plot training history
h = history.history
epochs = range(len(h['loss']))
plt.plot(epochs, h['loss'], '.-'), plt.grid(True)
plt.xlabel('epoch'), plt.ylabel('loss')
# Out:
# (Text(0.5, 0, 'epoch'), Text(0, 0.5, 'loss'))

# %%
# Let's also have a looks at the learnt weights
plt.plot(model.layers[1].weights[0].numpy(), '.-'), plt.grid(True)
print(model.layers[1].weights[1].numpy(), model.layers[1].bias.numpy())
# Out:
# [0.39754844] [0.39754844]

# %% [markdown]
# #### Performance Evaluation
#
# Once our model is trained, we will can run it on our images to see how it performs (inference).

# %%
idx = 50
pred = model.predict(pixels[idx:idx+1, ...])
print(pred, labels[idx])
# Out:
# 1/1 [==============================] - 0s 55ms/step
# [[0.6469885]] 1

# %%
# Run it on the entire dataset
predictions = model.predict(pixels).squeeze()
predictions = predictions > 0.5
# Out:
# 140/140 [==============================] - 0s 281us/step

# %%
correct = 0
for prediction, label in zip(predictions, labels):
    if prediction == label:
        correct = correct + 1

print('Accuracy', correct/len(labels))
# Out:
# Accuracy 0.9167785234899329

# %%
for cnt, idx in enumerate(np.random.randint(0, len(images), 10)): 
    plt.subplot(2,5,cnt+1), plt.imshow(images[idx], cmap='gray', vmin=0, vmax=255)
    plt.title('Label: ' + str(labels[idx]) + ' | Prediction: ' + str(predictions[idx]))
    plt.axis(False)

# %%
# Building the Neural Network
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input, Dropout

inputs = Input(shape=(pixels.shape[1],))

# Add more neurons and layers
x = Dense(64, activation='relu')(inputs)  # Increased number of neurons, changed activation to 'relu'
x = Dropout(0.5)(x)  # Added dropout layer
x = Dense(32, activation='relu')(x)  # Added additional layer with 'relu' activation
x = Dropout(0.5)(x)  # Added dropout layer

outputs = Dense(1, activation='sigmoid')(x)  # Output layer with 'sigmoid' activation
model = Model(inputs, outputs)

model.summary()
tf.keras.utils.plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with more epochs
history = model.fit(pixels, labels, epochs=50, batch_size=32)  # Increased number of epochs

# Plot training history
h = history.history
epochs = range(len(h['loss']))
plt.plot(epochs, h['loss'], '.-', label='Loss')
plt.plot(epochs, h['accuracy'], '.-', label='Accuracy')
plt.grid(True)
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend()

# Let's also have a look at the learned weights
plt.figure()
plt.plot(model.layers[1].weights[0].numpy(), '.-')
plt.grid(True)

# Performance Evaluation
idx = 50
pred = model.predict(pixels[idx:idx+1, ...])
print(pred, labels[idx])

# Run it on the entire dataset
predictions = model.predict(pixels).squeeze()
predictions = predictions > 0.5
correct = np.sum(predictions == labels)
accuracy = correct / len(labels)

print('Accuracy', accuracy)

for cnt, idx in enumerate(np.random.randint(0, len(images), 10)): 
    plt.subplot(2,5,cnt+1), plt.imshow(images[idx], cmap='gray', vmin=0, vmax=255)
    plt.title('Label: ' + str(labels[idx]) + ' | Prediction: ' + str(predictions[idx]))
    plt.axis(False)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 784)]             0
#
#  dense_16 (Dense)            (None, 64)                50240
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_18 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 52,353
# Trainable params: 52,353
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# Epoch 1/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.7012 - accuracy: 0.5333
# Epoch 2/50
# 140/140 [==============================] - 0s 568us/step - loss: 0.6709 - accuracy: 0.5980
# Epoch 3/50
# 140/140 [==============================] - 0s 588us/step - loss: 0.6485 - accuracy: 0.6362
# Epoch 4/50
# 140/140 [==============================] - 0s 591us/step - loss: 0.6308 - accuracy: 0.6499
# Epoch 5/50
# 140/140 [==============================] - 0s 666us/step - loss: 0.5940 - accuracy: 0.6984
# Epoch 6/50
# 140/140 [==============================] - 0s 632us/step - loss: 0.5676 - accuracy: 0.7157
# Epoch 7/50
# 140/140 [==============================] - 0s 608us/step - loss: 0.5586 - accuracy: 0.7183
# Epoch 8/50
# 140/140 [==============================] - 0s 601us/step - loss: 0.5632 - accuracy: 0.6969
# Epoch 9/50
# 140/140 [==============================] - 0s 582us/step - loss: 0.5396 - accuracy: 0.7333
# Epoch 10/50
# 140/140 [==============================] - 0s 538us/step - loss: 0.5236 - accuracy: 0.7499
# Epoch 11/50
# 140/140 [==============================] - 0s 540us/step - loss: 0.5119 - accuracy: 0.7544
# Epoch 12/50
# 140/140 [==============================] - 0s 546us/step - loss: 0.4769 - accuracy: 0.7843
# Epoch 13/50
# 140/140 [==============================] - 0s 522us/step - loss: 0.5478 - accuracy: 0.7092
# Epoch 14/50
# 140/140 [==============================] - 0s 532us/step - loss: 0.5541 - accuracy: 0.7007
# Epoch 15/50
# 140/140 [==============================] - 0s 563us/step - loss: 0.5522 - accuracy: 0.7020
# Epoch 16/50
# 140/140 [==============================] - 0s 543us/step - loss: 0.5324 - accuracy: 0.7195
# Epoch 17/50
# 140/140 [==============================] - 0s 542us/step - loss: 0.5327 - accuracy: 0.7166
# Epoch 18/50
# 140/140 [==============================] - 0s 645us/step - loss: 0.5346 - accuracy: 0.7148
# Epoch 19/50
# 140/140 [==============================] - 0s 624us/step - loss: 0.4790 - accuracy: 0.7747
# Epoch 20/50
# 140/140 [==============================] - 0s 822us/step - loss: 0.4392 - accuracy: 0.8085
# Epoch 21/50
# 140/140 [==============================] - 0s 601us/step - loss: 0.4872 - accuracy: 0.7740
# Epoch 22/50
# 140/140 [==============================] - 0s 596us/step - loss: 0.4637 - accuracy: 0.7911
# Epoch 23/50
# 140/140 [==============================] - 0s 584us/step - loss: 0.4185 - accuracy: 0.8181
# Epoch 24/50
# 140/140 [==============================] - 0s 581us/step - loss: 0.4295 - accuracy: 0.8150
# Epoch 25/50
# 140/140 [==============================] - 0s 569us/step - loss: 0.4324 - accuracy: 0.8150
# Epoch 26/50
# 140/140 [==============================] - 0s 587us/step - loss: 0.4265 - accuracy: 0.8186
# Epoch 27/50
# 140/140 [==============================] - 0s 620us/step - loss: 0.4300 - accuracy: 0.8152
# Epoch 28/50
# 140/140 [==============================] - 0s 624us/step - loss: 0.4296 - accuracy: 0.8103
# Epoch 29/50
# 140/140 [==============================] - 0s 598us/step - loss: 0.4199 - accuracy: 0.8179
# Epoch 30/50
# 140/140 [==============================] - 0s 625us/step - loss: 0.3975 - accuracy: 0.8318
# Epoch 31/50
# 140/140 [==============================] - 0s 651us/step - loss: 0.3889 - accuracy: 0.8400
# Epoch 32/50
# 140/140 [==============================] - 0s 605us/step - loss: 0.4099 - accuracy: 0.8255
# Epoch 33/50
# 140/140 [==============================] - 0s 600us/step - loss: 0.3847 - accuracy: 0.8432
# Epoch 34/50
# 140/140 [==============================] - 0s 638us/step - loss: 0.3968 - accuracy: 0.8302
# Epoch 35/50
# 140/140 [==============================] - 0s 645us/step - loss: 0.3949 - accuracy: 0.8340
# Epoch 36/50
# 140/140 [==============================] - 0s 813us/step - loss: 0.3972 - accuracy: 0.8324
# Epoch 37/50
# 140/140 [==============================] - 0s 557us/step - loss: 0.4059 - accuracy: 0.8271
# Epoch 38/50
# 140/140 [==============================] - 0s 609us/step - loss: 0.3900 - accuracy: 0.8371
# Epoch 39/50
# 140/140 [==============================] - 0s 718us/step - loss: 0.3950 - accuracy: 0.8369
# Epoch 40/50
# 140/140 [==============================] - 0s 761us/step - loss: 0.3667 - accuracy: 0.8526
# Epoch 41/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8539
# Epoch 42/50
# 140/140 [==============================] - 0s 597us/step - loss: 0.3587 - accuracy: 0.8532
# Epoch 43/50
# 140/140 [==============================] - 0s 706us/step - loss: 0.3652 - accuracy: 0.8499
# Epoch 44/50
# 140/140 [==============================] - 0s 616us/step - loss: 0.4063 - accuracy: 0.8289
# Epoch 45/50
# 140/140 [==============================] - 0s 627us/step - loss: 0.3968 - accuracy: 0.8329
# Epoch 46/50
# 140/140 [==============================] - 0s 598us/step - loss: 0.3544 - accuracy: 0.8584
# Epoch 47/50
# 140/140 [==============================] - 0s 618us/step - loss: 0.3948 - accuracy: 0.8405
# Epoch 48/50
# 140/140 [==============================] - 0s 642us/step - loss: 0.4316 - accuracy: 0.8098
# Epoch 49/50
# 140/140 [==============================] - 0s 625us/step - loss: 0.4537 - accuracy: 0.7944
# Epoch 50/50
# 140/140 [==============================] - 0s 576us/step - loss: 0.4299 - accuracy: 0.8063
# 1/1 [==============================] - 0s 21ms/step
# [[0.9263013]] 1
# 140/140 [==============================] - 0s 352us/step
# Accuracy 0.9422818791946309
